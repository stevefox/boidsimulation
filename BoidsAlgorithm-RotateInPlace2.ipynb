# %% [markdown]
# # SYSM 6302 Final Project: The Boids Algorithm
# ## [Steve Fox](http://www.stevefox.io)
#
# The *Boids Algorithm* is a mathematical model of flocking behavior. The flocking behavior of fish, birds and [stampedes of animals (as in Disney's *The Lion King*)](http://www.lionking.org/movies/Stampede.mov) [4] can be simulated using a simple distributed computational paradigm where each actor in the flock responds only to its local surrounding. The original application of the boids algorithm was for animation (computer graphics), but the literature of output synchronization of systems with localized perception, such as mobile robots, is growing (cite papers).
#
# Consider how you, too, may be a boid in a crowd. How do people behave at a concert, or waiting in line for a crowded public event? The average person might try to maintain a small space between him or her and the others, to avoid being jostled around. That person will also try to keep the same speed as those around them: if he slows down too much, you might get trampled; if he goes too fast, he will be jostling the people around him. Further, anybody who is anybody wants to be in the center of the crowd, because the center of the crowd is where anybody who's anybody is. It is simple economics: that's the best place to be (for, perhaps, tangible or intangible reasons). In a natural flock, the center of the flock might be *safer* from predators. Finally, there may be some selfish or globally minded goal-oriented behavior: get to the front of the stage first, or get the best patch of grass when the venue opens.
#
# Craig W. Reynolds published a paper in July of 1987 titled "Flocks, Herds, and Schools: A Distributed Behavioral Model" describing this behavior for the first time for efficient animation of crowds and flocks. [1] The intent of the paper was to share a computationally feasible method of rendering flocks for computer-generated animations. The computational complexity along with the difficult nature of specifying exact individual paths in large "flocks" (of people, animals, etc...) served as an impetus to explore a more feasible means of simulating the type of behavior exhibited by groups of objects. The boids algorithm is described very succinctly in [Steve Strogatz's](http://www.stevenstrogatz.com/) [Ted Talk on Syncrhonization in Nature](http://www.ted.com/talks/steven_strogatz_on_sync.html) with footage of flocks of birds and schools of fish found in nature (and majestic music in the background).
#
# ## Model of the Boid
# _Boids_ (definition): The word _boid_ is short for _bird-oid_, or a "bird-like object". A _flock_ of boids is one whose emergent behavior displays the characteristics of natural flocks, herds and schools of animals. Simulating these behavioral characteristics is based on three local navigation rules for each _boid_ in the flock:
#
# ![boid](files/img/boid-red.png "A 2D, directional boid")
#
# 1. **Collision Avoidance**: Boids (or static or moving obstacles) within a
#
#
# 1. **Velocity Matching**:
#
# 1. **Flock Centering**:

# %%
#: PyGame Skeleton Code based on Tutorial located at: http://www.pygame.org/docs/tut/intro/intro.html [2]
import sys, pygame
from pygame.locals import *
from math import ceil
from math import cos, sin
from random import randint
# For linear algebra
import numpy as np
import pygame 

from copy import deepcopy # cheap hack; shot myself in the foot with python references in the list

# Model the Boid as an object, as Reynolds suggests in the paper 
# (OOP was not as popular back in 1987; this was originally done in Common LISP)

###################################################################################################################################################
# Model of the Boid
#   * Could be considered an animal, such as a fish or bird, or a robot
#   * Can only "see" within a small distance (a couple of body lengths), which I call the parameter "neighbor_distance"
#   * The naive complexity is in O(n^2), but it only takes each actor constant time
#       * A massive implementation could use a spatially sorted datastructure such as kD-tree (quad-tree in two dimensions, 
#         octree in three dimensions) for fast approximate nearest neighbors
#   * Resulting behavior is often referred to in the literature as "Emergent Behavior"
#   * If you think the type of dynamical system is interesting, check out cellular automata [5]
#
# Rules
#   * Rule 1: Tries to stay at least "safe_distance" away from its neighbors
#   * Rule 2: Tries to fly toward the center of mass of all neighbors within "neighbor_distance"
#   * Rule 3: Tries to match velocity with the neighbors within neighbor_distance
#
# Coordinate System
#   * The coordinate system in pygame has (0,0) in the top left corner, with "+x" horizontal to the right, and "+y" vertically pointing downward.
###################################################################################################################################################

def saturate(value, max_value):
    if abs(value) > max_value:
        return np.sign(value)*max_value
    return value

class Boid:
    #: Initialize the boid at some position x,y
    def __init__(self, x, y, angle, image_surface):
        
        ###########################################################################################################################################
        # Dynamical State
        ###########################################################################################################################################
        #: position
        self.pos = np.array([x, y]) # [px] right = +x, down = +y, (0,0) in top left corner
        self.angle = angle # [deg] up = +x = 0[deg], left = +y = 90[deg]; current heading
                
        #: velocity
        # [x, y]
        self.vel = np.array([0.,0.])
        self.rot_vel = 0.0
        #: acceleration (this is what the rules affect)
        # [translational, rotational]
        self.accel = np.array([0.0, 0.0])
        self.a2 = np.array([0.,0.])
        
        ############################################################################################################################################
        # Rendering
        ############################################################################################################################################
        #: image & rendering surfaces
        self.image_surface = image_surface
        self.surf = pygame.Surface((51,51),flags=pygame.SRCALPHA)
        self.surf.set_alpha(0)
        tmp_rect = self.image_surface.get_rect()
        self.pos_rect = pygame.Rect((16,16,17,17))
        self.surf.blit(image_surface, self.pos_rect)
        
        ############################################
        #: Boid Parameters
        ############################################
        self.max_vel = np.array([20., 20.])
        self.max_accel = np.array([15., 15.]) # magnitude [px] / frame; rotational [deg] / frame
        self.repulsion_coef = 0.5
        self.max_rot_vel = 5
    def __repr__(self):
        return "%.0f,%.0f:%.0f,%.0f " % (self.pos[0], self.pos[1], self.vel[0], self.vel[1]) 
    
    def draw(self):
        #: Rotate the image to the desired heading
        render_angle = -(self.angle+90)
        render_surf = pygame.transform.rotozoom(self.surf, render_angle, 1.0)
        #: Crop the Surface box
        rot_rect = render_surf.get_rect(center=(self.pos[0], self.pos[1]))
        #: Overlay heading
        font = pygame.font.Font(None, 12)
        text = font.render(str(self), 1, (255, 255, 255))
        r = text.get_rect()
        render_surf.blit(text, r)
        screen.blit(render_surf, rot_rect)
    
    def update(self, neighbors, close_neighbors):
        #: apply all rules
        self.accel = np.array([0., 0.])
        
        a1 = self.__avoid(close_neighbors)
        a2 = self.__centering(neighbors)
        a3, rot_vel = self.__velocity(neighbors)
       
        self.accel = 0.05*a1
   
        if np.linalg.norm(self.accel) < self.max_accel[0]:
           new_accel = self.accel + 0.01*a2
           if np.linalg.norm(self.accel) < self.max_accel[0]:
               self.accel = new_accel
        if np.linalg.norm(self.accel) < self.max_accel[0]:
            new_accel = self.accel + 0.05*a3
            if np.linalg.norm(new_accel) < self.max_accel[0]:
                self.accel = new_accel
                
        self.vel += self.accel 
        
        if np.linalg.norm(self.vel) > self.max_vel[0]:
            self.vel /= np.linalg.norm(self.vel)
            self.vel *= self.max_vel[0]
        
        if np.linalg.norm(self.vel) != 0:
            dir_mvt = np.rad2deg(np.arctan2(self.vel[1],self.vel[0]))
            self.angle = dir_mvt
            self.angle %= 360
       
        self.pos += self.vel
        #self.pos[0] -= self.vel[0]*sin(np.deg2rad(self.vel[1]))
        #self.pos[0] += a1[0]
        self.pos[0] %= 1024 # wrap to screen
        #self.pos[1] -=self.vel[0]*cos(np.deg2rad(self.vel[1]))
        #self.pos[1] += a1[1]
        self.pos[1] %= 768 # wrap to screen
    
    ##################################
    # Rules in Order of Precedence
    ##################################
    #: Rule 1: Collision Avoidance
    def __avoid(self, close_neighbors):
        c = np.array([0.,0.])
        for i in close_neighbors:
            
            c -= (self.pos - i[0].pos)/i[1]*(1.0/(i[1]**3)) #*(1.0/i[1]**2) # repulsion is inverse exponentially repulsed by the object
            if i[1] == 0:
                c -= i[0].vel
        
        return c
    #: Rule 2: Velocity Matching
    def __velocity(self, neighbors):
        if len(neighbors) == 0:
            return self.vel, self.rot_vel
        sum_vel = np.array([0.,0.])
        sum_rot_vel = 0.
        for i in neighbors:
            sum_vel += i[0].vel
            sum_rot_vel += i[0].rot_vel
        sum_vel /= len(neighbors)
        sum_rot_vel /= len(neighbors)
        
        return sum_vel, sum_rot_vel
    #: Rule 3: Flock Centering
    def __centering(self, neighbors):
        center = np.array([0.,0.])
        
        if len(neighbors) == 0:
            return center
            
        for i in neighbors:
            center += i[0].pos
        
        center /= len(neighbors)
        # compute the direction to the center from current position
        accel_request = (center - self.pos) # vector in pixels
        
        return accel_request
    
class Flock:
    #: Initializes a flock of @param count boids. Note that birds of a feather
    #: flock together, but that a property of boids is that they can split up
    #: Pseudocode from [3] is adapted here
    def __init__(self, count, safe_distance, neighbor_distance):
        image_surface = pygame.image.load("img/boid-red.png").convert_alpha()
        self.safe_distance = safe_distance # [pixels]; 3 * 20 [px] = 3 body lengths
        self.neighbor_distance = neighbor_distance
        self.boid_list = [ Boid(randint(1,1023), randint(1,768), randint(0,360), image_surface) for i in range(count) ]
    #: Render the flock
    def draw(self):
        for i in self.boid_list:
            i.draw()
    def update(self):
        static_boid_list = self.boid_list[:] # need to research how to avoid this nonsense
        for i in self.boid_list:
            # find all neighbors within a radius=safe_distance
            close_neighbors = []
            neighbors = []
            for j in static_boid_list:
                vector_diff = i.pos-j.pos
                distance = np.linalg.norm(vector_diff)
                if j == i:
                    continue
                if distance < self.safe_distance:
                    close_neighbors.append( (j, distance) )
                if distance < self.neighbor_distance:
                    neighbors.append( (j,distance) )
            i.update(neighbors, close_neighbors)
            print 'done with',i

# %%
#: Setup the pygame Game Engine [2]
pygame.init()
fpsClock = pygame.time.Clock()

#: Configure the screen size (not resizable)
width = 1024
height = 768
size = (width, height)

black = 1.0, 1.0, 1.0
white = 0.0, 0.0, 0.0
screen = pygame.display.set_mode(size)
pygame.display.set_caption("Interactive Boid's Algorithm Simulation")

#: Create and render the initial flock
f = Flock(10, 30., 500.) # 50 [boids], 60 [pixels between boids], 
f.draw()
pygame.display.flip()

#: Start the simulation
while True:
    fpsClock.tick(30)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            sys.exit()
        if event.type == pygame.KEYDOWN:
            if event.key == K_ESCAPE:
                pygame.event.post(pygame.event.Event(QUIT))
    if True:
                screen.fill(black)
                f.update()
                f.draw()
                pygame.display.flip()
# Out:
#  533,314:-35,-3
# done with 0,256:nan,nan
# done with 442,336:-35,-6
# done with 0,256:nan,nan
# done with 346,234:-35,1
# done with 351,230:-35,2
# done with 485,312:-35,-4
# done with 438,329:-35,-5
# done with 473,309:-35,-4
# done with 0,256:nan,nan
# done with 498,310:-35,-3
# done with 0,256:nan,nan
# done with 407,329:-34,-6
# done with 0,256:nan,nan
# done with 311,235:-35,2
# done with 316,232:-35,2
# done with 450,308:-35,-4
# done with 403,323:-35,-5
# done with 438,305:-35,-4
# done with 0,256:nan,nan
# done with
#  463,306:-35,-3
# done with 0,256:nan,nan
# done with 372,322:-34,-6
# done with 0,256:nan,nan
# done with 276,237:-35,2
# done with 281,234:-35,3
# done with 415,304:-35,-4
# done with 368,317:-35,-6
# done with 403,301:-35,-4
# done with 0,256:nan,nan
# done with 428,302:-35,-4
# done with 0,256:nan,nan
# done with 337,315:-34,-7
# done with 0,256:nan,nan
# done with 241,239:-35,3
# done with 246,237:-35,3
# done with 380,300:-35,-4
# done with 333,311:-35,-6
# done with 368,297:-35,-4
# done with 0,256:nan,nan
# done with
#  393,298:-35,-4
# done with 0,256:nan,nan
# done with 302,308:-34,-7
# done with 0,256:nan,nan
# done with 206,242:-35,3
# done with 211,240:-35,4
# done with 345,296:-35,-4
# done with 298,305:-34,-6
# done with 333,292:-35,-4
# done with 0,256:nan,nan
# done with 358,294:-35,-4
# done with 0,256:nan,nan
# done with 267,301:-34,-7
# done with 0,256:nan,nan
# done with 171,245:-35,4
# done with 176,244:-35,4
# done with 310,292:-35,-4
# done with 263,298:-34,-6
# done with 298,287:-35,-4
# done with 0,256:nan,nan
# done with
#  323,290:-35,-4
# done with 0,256:nan,nan
# done with 232,293:-34,-7
# done with 0,256:nan,nan
# done with 136,248:-35,4
# done with 141,248:-35,4
# done with 275,287:-35,-4
# done with 228,291:-34,-6
# done with 263,282:-35,-4
# done with 0,256:nan,nan
# done with 288,286:-35,-4
# done with 0,256:nan,nan
# done with 197,285:-34,-7
# done with 0,256:nan,nan
# done with 101,252:-35,4
# done with 106,252:-35,5
# done with 240,282:-35,-4
# done with 193,284:-34,-6
# done with 228,277:-35,-4
# done with 0,256:nan,nan
# done with
#  253,282:-35,-4
# done with 0,256:nan,nan
# done with 162,277:-34,-7
# done with 0,256:nan,nan
# done with 66,256:-34,4
# done with 71,256:-34,5
# done with 205,277:-35,-4
# done with 158,277:-34,-6
# done with 193,273:-35,-4
# done with 0,256:nan,nan
# done with 218,278:-35,-4
# done with 0,256:nan,nan
# done with 127,269:-34,-7
# done with 0,256:nan,nan
# done with 32,260:-34,4
# done with 36,260:-34,5
# done with 170,272:-35,-4
# done with 123,270:-34,-6
# done with 158,269:-35,-4
# done with 0,256:nan,nan
# done with
#  183,274:-35,-4
# done with 0,256:nan,nan
# done with 92,261:-34,-7
# done with 0,256:nan,nan
# done with 1023,264:-33,4
# done with 2,265:-34,5
# done with 135,268:-35,-4
# done with 88,263:-34,-6
# done with 123,265:-35,-4
# done with 0,256:nan,nan
# done with 148,270:-35,-4
# done with 0,256:nan,nan
# done with 57,253:-34,-7
# done with 0,256:nan,nan
# done with 988,268:-35,5
# done with 994,269:-33,5
# done with 100,264:-35,-4
# done with 53,256:-34,-6
# done with 88,261:-35,-4
# done with 0,256:nan,nan
# done with
#  113,266:-35,-4
# done with 0,256:nan,nan
# done with 22,245:-34,-7
# done with 0,256:nan,nan
# done with 953,272:-35,5
# done with 959,274:-35,5
# done with 65,260:-35,-4
# done with 18,249:-34,-6
# done with 53,257:-35,-4
# done with 0,256:nan,nan
# done with 78,262:-35,-4
# done with 0,256:nan,nan
# done with 1012,238:-34,-7
# done with 0,256:nan,nan
# done with 918,276:-35,4
# done with 924,278:-35,5
# done with 30,256:-35,-4
# done with 1008,242:-34,-6
# done with 18,253:-35,-4
# done with 0,256:nan,nan
# done with
#  43,258:-35,-4
# done with 0,256:nan,nan
# done with 977,231:-34,-6
# done with 0,256:nan,nan
# done with 883,279:-35,4
# done with 889,282:-35,4
# done with 1020,252:-35,-4
# done with 973,236:-35,-6
# done with 1008,249:-35,-4
# done with 0,256:nan,nan
# done with 8,254:-35,-4
# done with 0,256:nan,nan
# done with 942,225:-35,-6
# done with 0,256:nan,nan
# done with 848,282:-35,3
# done with 854,285:-35,4
# done with 985,248:-35,-4
# done with 938,230:-35,-5
# done with 973,245:-35,-4
# done with 0,256:nan,nan
# done with
#  998,250:-35,-4
# done with 0,256:nan,nan
# done with 907,219:-35,-5
# done with 0,256:nan,nan
# done with 813,284:-35,3
# done with 819,287:-35,3
# done with 950,244:-35,-4
# done with 903,225:-35,-5
# done with 938,241:-35,-3
# done with 0,256:nan,nan
# done with 963,246:-35,-3
# done with 0,256:nan,nan
# done with 872,214:-35,-5
# done with 0,256:nan,nan
# done with 778,286:-35,2
# done with 784,289:-35,2
# done with 915,240:-35,-3
# done with 868,220:-35,-4
# done with 903,237:-35,-3
# done with 0,256:nan,nan
# done with
#  928,242:-35,-3
# done with 0,256:nan,nan
# done with 837,209:-35,-4
# done with 0,256:nan,nan
# done with 743,287:-35,1
# done with 749,290:-35,2
# done with 880,236:-35,-3
# done with 833,216:-35,-4
# done with 868,234:-35,-3
# done with 0,256:nan,nan
# done with 893,238:-35,-3
# done with 0,256:nan,nan
# done with 802,205:-35,-4
# done with 0,256:nan,nan
# done with 708,287:-35,1
# done with 714,290:-35,1
# done with 845,233:-35,-3
# done with 798,212:-35,-3
# done with 833,231:-35,-3
# done with 0,256:nan,nan
# done with
#  858,235:-35,-3
# done with 0,256:nan,nan
# done with 767,201:-35,-3
# done with 0,256:nan,nan
# done with 673,287:-35,0
# done with 679,290:-35,0
# done with 810,230:-35,-3
# done with 763,209:-35,-3
# done with 798,228:-35,-3
# done with 0,256:nan,nan
# done with 823,232:-35,-3
# done with 0,256:nan,nan
# done with 732,198:-35,-3
# done with 0,256:nan,nan
# done with 638,286:-35,-0
# done with 644,289:-35,-0
# done with 775,227:-35,-3
# done with 728,206:-35,-3
# done with 763,225:-35,-2
# done with 0,256:nan,nan
# done with
#  788,229:-35,-3
# done with 0,256:nan,nan
# done with 697,195:-35,-2
# done with 0,256:nan,nan
# done with 603,284:-35,-1
# done with 609,287:-35,-1
# done with 740,224:-35,-2
# done with 693,203:-35,-2
# done with 728,222:-35,-2
# done with 0,256:nan,nan
# done with 753,226:-35,-2
# done with 0,256:nan,nan
# done with 662,193:-35,-2
# done with 0,256:nan,nan
# done with 568,282:-35,-2
# done with 574,285:-35,-2
# done with 705,221:-35,-2
# done with 658,201:-35,-2
# done with 693,219:-35,-2
# done with 0,256:nan,nan
# done with
#  718,223:-35,-2
# done with 0,256:nan,nan
# done with 627,191:-35,-1
# done with 0,256:nan,nan
# done with 533,279:-35,-2
# done with 539,282:-35,-2
# done with 670,218:-35,-2
# done with 623,199:-35,-2
# done with 658,217:-35,-2
# done with 0,256:nan,nan
# done with 683,220:-35,-2
# done with 0,256:nan,nan
# done with 592,190:-35,-1
# done with 0,256:nan,nan
# done with 498,276:-35,-3
# done with 504,278:-35,-3
# done with 635,216:-35,-2
# done with 588,197:-35,-1
# done with 623,215:-35,-2
# done with 0,256:nan,nan
# done with
#  648,218:-35,-2
# done with 0,256:nan,nan
# done with 557,189:-35,-1
# done with 0,256:nan,nan
# done with 463,272:-35,-3
# done with 469,274:-35,-4
# done with 600,214:-35,-2
# done with 553,196:-35,-1
# done with 588,213:-35,-2
# done with 0,256:nan,nan
# done with 613,216:-35,-2
# done with 0,256:nan,nan
# done with 522,188:-35,-0
# done with 0,256:nan,nan
# done with 428,268:-35,-4
# done with 434,269:-35,-4
# done with 565,212:-35,-2
# done with 518,195:-35,-1
# done with 553,211:-35,-1
# done with 0,256:nan,nan
# done with
#  578,214:-35,-2
# done with 0,256:nan,nan
# done with 487,188:-35,0
# done with 0,256:nan,nan
# done with 393,264:-35,-4
# done with 399,264:-35,-4
# done with 530,210:-35,-2
# done with 483,194:-35,-0
# done with 518,209:-35,-1
# done with 0,256:nan,nan
# done with 543,212:-35,-2
# done with 0,256:nan,nan
# done with 452,188:-35,1
# done with 0,256:nan,nan
# done with 358,259:-35,-4
# done with 364,259:-35,-5
# done with 495,208:-35,-1
# done with 448,193:-35,-0
# done with 483,207:-35,-1
# done with 0,256:nan,nan
# done with
#  508,210:-35,-1
# done with 0,256:nan,nan
# done with 417,188:-35,1
# done with 0,256:nan,nan
# done with 323,254:-35,-4
# done with 329,254:-35,-5
# done with 460,206:-35,-1
# done with 413,193:-35,0
# done with 448,206:-35,-1
# done with 0,256:nan,nan
# done with 473,208:-35,-1
# done with 0,256:nan,nan
# done with 382,189:-35,1
# done with 0,256:nan,nan
# done with 288,249:-35,-5
# done with 294,248:-35,-5
# done with 425,205:-35,-1
# done with 378,193:-35,1
# done with 413,205:-35,-1
# done with 0,256:nan,nan
# done with
#  438,206:-35,-1
# done with 0,256:nan,nan
# done with 347,190:-35,2
# done with 0,256:nan,nan
# done with 253,244:-35,-5
# done with 259,242:-35,-5
# done with 390,204:-35,-1
# done with 343,193:-35,1
# done with 378,204:-35,-0
# done with 0,256:nan,nan
# done with 403,205:-35,-1
# done with 0,256:nan,nan
# done with 312,192:-35,2
# done with 0,256:nan,nan
# done with 218,238:-35,-5
# done with 224,236:-35,-5
# done with 355,203:-35,-0
# done with 308,194:-35,1
# done with 343,203:-35,-0
# done with 0,256:nan,nan
# done with
#  368,204:-35,-1
# done with 0,256:nan,nan
# done with 277,194:-35,2
# done with 0,256:nan,nan
# done with 183,232:-35,-5
# done with 189,230:-35,-5
# done with 320,202:-35,-0
# done with 273,195:-35,2
# done with 308,203:-35,0
# done with 0,256:nan,nan
# done with 333,203:-35,-0
# done with 0,256:nan,nan
# done with 242,196:-35,3
# done with 0,256:nan,nan
# done with 148,226:-35,-5
# done with 154,224:-35,-6
# done with 285,202:-35,0
# done with 238,196:-35,2
# done with 273,203:-35,0
# done with 0,256:nan,nan
# done with
#  298,202:-35,-0
# done with 0,256:nan,nan
# done with 207,198:-35,3
# done with 0,256:nan,nan
# done with 113,220:-34,-5
# done with 119,218:-35,-6
# done with 250,202:-35,0
# done with 203,197:-35,2
# done with 238,203:-35,0
# done with 0,256:nan,nan
# done with 263,202:-35,0
# done with 0,256:nan,nan
# done with 172,200:-35,3
# done with 0,256:nan,nan
# done with 78,214:-34,-5
# done with 84,212:-34,-6
# done with 215,202:-35,0
# done with 168,199:-35,2
# done with 203,203:-35,1
# done with 0,256:nan,nan
# done with
#  228,202:-35,0
# done with 0,256:nan,nan
# done with 137,203:-35,3
# done with 0,256:nan,nan
# done with 44,208:-34,-5
# done with 49,206:-34,-5
# done with 180,202:-35,1
# done with 133,201:-35,2
# done with 168,203:-35,1
# done with 0,256:nan,nan
# done with 193,202:-35,0
# done with 0,256:nan,nan
# done with 102,206:-35,3
# done with 0,256:nan,nan
# done with 10,202:-33,-5
# done with 15,200:-34,-5
# done with 145,202:-35,1
# done with 98,203:-35,2
# done with 133,203:-35,1
# done with 0,256:nan,nan
# done with
#  158,202:-35,1
# done with 0,256:nan,nan
# done with 67,209:-35,3
# done with 0,256:nan,nan
# done with 1002,197:-33,-5
# done with 1006,194:-33,-5
# done with 110,203:-35,1
# done with 63,205:-35,3
# done with 98,204:-35,1
# done with 0,256:nan,nan
# done with 123,202:-35,1
# done with 0,256:nan,nan
# done with 32,212:-35,3
# done with 0,256:nan,nan
# done with 967,191:-34,-5
# done with 971,188:-35,-5
# done with 75,204:-35,1
# done with 28,207:-35,3
# done with 63,205:-35,1
# done with 0,256:nan,nan
# done with
#  88,203:-35,1
# done with 0,256:nan,nan
# done with 1022,215:-35,4
# done with 0,256:nan,nan
# done with 932,185:-35,-5
# done with 936,183:-35,-5
# done with 40,205:-35,1
# done with 1018,210:-35,3
# done with 28,206:-35,2
# done with 0,256:nan,nan
# done with 53,204:-35,1
# done with 0,256:nan,nan
# done with 987,218:-35,3
# done with 0,256:nan,nan
# done with 897,180:-35,-5
# done with 901,178:-35,-5
# done with 5,206:-35,2
# done with 983,212:-35,3
# done with 1018,207:-35,2
# done with 0,256:nan,nan
# done with
#  18,205:-35,2
# done with 0,256:nan,nan
# done with 952,220:-35,3
# done with 0,256:nan,nan
# done with 862,175:-35,-4
# done with 866,173:-35,-4
# done with 995,208:-35,2
# done with 948,214:-35,2
# done with 983,208:-35,2
# done with 0,256:nan,nan
# done with 1008,207:-35,2
# done with 0,256:nan,nan
# done with 917,222:-35,2
# done with 0,256:nan,nan
# done with 827,171:-35,-4
# done with 831,169:-35,-4
# done with 960,209:-35,2
# done with 913,216:-35,2
# done with 948,209:-35,1
# done with 0,256:nan,nan
# done with
#  973,208:-35,2
# done with 0,256:nan,nan
# done with 882,223:-35,2
# done with 0,256:nan,nan
# done with 792,167:-35,-3
# done with 796,165:-35,-3
# done with 925,210:-35,2
# done with 878,217:-35,2
# done with 913,210:-35,1
# done with 0,256:nan,nan
# done with 938,209:-35,2
# done with 0,256:nan,nan
# done with 847,224:-35,2
# done with 0,256:nan,nan
# done with 757,164:-35,-3
# done with 761,162:-35,-3
# done with 890,211:-35,1
# done with 843,218:-35,1
# done with 878,211:-35,1
# done with 0,256:nan,nan
# done with
#  903,210:-35,2
# done with 0,256:nan,nan
# done with 812,225:-35,1
# done with 0,256:nan,nan
# done with 722,161:-35,-2
# done with 726,159:-35,-2
# done with 855,212:-35,1
# done with 808,219:-35,1
# done with 843,211:-35,1
# done with 0,256:nan,nan
# done with 868,211:-35,1
# done with 0,256:nan,nan
# done with 777,225:-35,1
# done with 0,256:nan,nan
# done with 687,159:-35,-2
# done with 691,157:-35,-2
# done with 820,213:-35,1
# done with 773,219:-35,1
# done with 808,211:-35,1
# done with 0,256:nan,nan
# done with
#  833,212:-35,1
# done with 0,256:nan,nan
# done with 742,225:-35,1
# done with 0,256:nan,nan
# done with 652,157:-35,-1
# done with 656,155:-35,-1
# done with 785,213:-35,1
# done with 738,219:-35,1
# done with 773,211:-35,1
# done with 0,256:nan,nan
# done with 798,212:-35,1
# done with 0,256:nan,nan
# done with 707,225:-35,0
# done with 0,256:nan,nan
# done with 617,156:-35,-1
# done with 621,154:-35,-0
# done with 750,213:-35,1
# done with 703,219:-35,0
# done with 738,211:-35,0
# done with 0,256:nan,nan
# done with
#  763,212:-35,1
# done with 0,256:nan,nan
# done with 672,224:-35,-0
# done with 0,256:nan,nan
# done with 582,155:-35,-0
# done with 586,154:-35,0
# done with 715,213:-35,0
# done with 668,219:-35,0
# done with 703,211:-35,0
# done with 0,256:nan,nan
# done with 728,212:-35,0
# done with 0,256:nan,nan
# done with 637,223:-35,-0
# done with 0,256:nan,nan
# done with 547,155:-35,0
# done with 551,154:-35,1
# done with 680,213:-35,0
# done with 633,218:-35,-0
# done with 668,211:-35,0
# done with 0,256:nan,nan
# done with
#  693,212:-35,0
# done with 0,256:nan,nan
# done with 602,222:-35,-1
# done with 0,256:nan,nan
# done with 512,155:-35,1
# done with 516,155:-35,1
# done with 645,213:-35,0
# done with 598,217:-35,-0
# done with 633,210:-35,-0
# done with 0,256:nan,nan
# done with 658,212:-35,0
# done with 0,256:nan,nan
# done with 567,221:-35,-1
# done with 0,256:nan,nan
# done with 477,156:-35,1
# done with 481,156:-35,2
# done with 610,212:-35,-0
# done with 563,216:-35,-0
# done with 598,209:-35,-0
# done with 0,256:nan,nan
# done with
#  623,211:-35,-0
# done with 0,256:nan,nan
# done with 532,220:-35,-1
# done with 0,256:nan,nan
# done with 442,157:-35,2
# done with 446,158:-35,2
# done with 575,211:-35,-0
# done with 528,215:-35,-1
# done with 563,208:-35,-0
# done with 0,256:nan,nan
# done with 588,210:-35,-0
# done with 0,256:nan,nan
# done with 497,218:-35,-1
# done with 0,256:nan,nan
# done with 407,159:-35,2
# done with 411,160:-35,3
# done with 540,210:-35,-0
# done with 493,214:-35,-1
# done with 528,207:-35,-0
# done with 0,256:nan,nan
# done with
#  553,209:-35,-0
# done with 0,256:nan,nan
# done with 462,216:-35,-1
# done with 0,256:nan,nan
# done with 372,161:-35,3
# done with 376,163:-35,3
# done with 505,209:-35,-0
# done with 458,213:-35,-1
# done with 493,206:-35,-0
# done with 0,256:nan,nan
# done with 518,208:-35,-0
# done with 0,256:nan,nan
# done with 427,214:-35,-1
# done with 0,256:nan,nan
# done with 337,164:-35,3
# done with 341,166:-35,4
# done with 470,208:-35,-0
# done with 423,212:-35,-1
# done with 458,205:-35,-0
# done with 0,256:nan,nan
# done with
#  483,207:-35,-0
# done with 0,256:nan,nan
# done with 392,212:-35,-1
# done with 0,256:nan,nan
# done with 302,167:-35,4
# done with 306,170:-35,4
# done with 435,207:-35,-0
# done with 388,211:-35,-1
# done with 423,204:-35,-0
# done with 0,256:nan,nan
# done with 448,206:-35,-0
# done with 0,256:nan,nan
# done with 357,210:-35,-1
# done with 0,256:nan,nan
# done with 267,171:-35,4
# done with 271,174:-35,5
# done with 400,206:-35,-0
# done with 353,210:-35,-1
# done with 388,203:-35,-0
# done with 0,256:nan,nan
# done with
#  413,205:-35,-0
# done with 0,256:nan,nan
# done with 322,209:-35,-1
# done with 0,256:nan,nan
# done with 232,175:-35,5
# done with 236,178:-35,5
# done with 365,205:-35,-0
# done with 318,209:-35,-0
# done with 353,203:-35,0
# done with 0,256:nan,nan
# done with 378,204:-35,-0
# done with 0,256:nan,nan
# done with 287,208:-35,-1
# done with 0,256:nan,nan
# done with 197,180:-35,5
# done with 201,183:-35,5
# done with 330,204:-35,-0
# done with 283,208:-35,-0
# done with 318,203:-35,0
# done with 0,256:nan,nan
# done with
#  343,204:-35,0
# done with 0,256:nan,nan
# done with 252,207:-35,-1
# done with 0,256:nan,nan
# done with 162,185:-35,6
# done with 166,188:-35,6
# done with 295,204:-35,0
# done with 248,207:-35,-0
# done with 283,203:-35,0
# done with 0,256:nan,nan
# done with 308,204:-35,0
# done with 0,256:nan,nan
# done with 217,206:-35,-1
# done with 0,256:nan,nan
# done with 127,190:-34,6
# done with 131,193:-34,6
# done with 260,204:-35,0
# done with 213,206:-35,-0
# done with 248,203:-35,0
# done with 0,256:nan,nan
# done with
#  273,204:-35,0
# done with 0,256:nan,nan
# done with 182,205:-35,-0
# done with 0,256:nan,nan
# done with 92,196:-34,6
# done with 96,199:-34,6
# done with 225,204:-35,0
# done with 178,206:-35,0
# done with 213,203:-35,1
# done with 0,256:nan,nan
# done with 238,204:-35,0
# done with 0,256:nan,nan
# done with 147,204:-35,-0
# done with 0,256:nan,nan
# done with 58,202:-34,7
# done with 61,205:-34,6
# done with 190,204:-35,1
# done with 143,206:-35,0
# done with 178,203:-35,1
# done with 0,256:nan,nan
# done with
#  203,204:-35,1
# done with 0,256:nan,nan
# done with 112,203:-35,-0
# done with 0,256:nan,nan
# done with 24,208:-34,7
# done with 27,211:-34,7
# done with 155,204:-35,1
# done with 108,206:-35,0
# done with 143,203:-35,1
# done with 0,256:nan,nan
# done with 168,204:-35,1
# done with 0,256:nan,nan
# done with 77,203:-35,0
# done with 0,256:nan,nan
# done with 1015,214:-33,7
# done with 1018,217:-33,7
# done with 120,204:-35,1
# done with 73,206:-35,1
# done with 108,204:-35,1
# done with 0,256:nan,nan
# done with
#  133,204:-35,1
# done with 0,256:nan,nan
# done with 42,203:-35,0
# done with 0,256:nan,nan
# done with 980,221:-34,7
# done with 983,223:-34,7
# done with 85,205:-35,1
# done with 38,206:-35,1
# done with 73,205:-35,1
# done with 0,256:nan,nan
# done with 98,205:-35,1
# done with 0,256:nan,nan
# done with 7,203:-35,1
# done with 0,256:nan,nan
# done with 945,228:-34,7
# done with 948,229:-34,7
# done with 50,206:-35,1
# done with 3,206:-35,1
# done with 38,206:-35,2
# done with 0,256:nan,nan
# done with
#  63,206:-35,1
# done with 0,256:nan,nan
# done with 997,203:-35,1
# done with 0,256:nan,nan
# done with 910,234:-34,7
# done with 913,235:-34,7
# done with 15,207:-35,2
# done with 993,207:-35,1
# done with 3,207:-35,2
# done with 0,256:nan,nan
# done with 28,207:-35,2
# done with 0,256:nan,nan
# done with 962,204:-35,1
# done with 0,256:nan,nan
# done with 875,240:-34,7
# done with 878,241:-34,6
# done with 1005,208:-35,2
# done with 958,208:-35,1
# done with 993,209:-35,2
# done with 0,256:nan,nan
# done with
#  1018,209:-35,2
# done with 0,256:nan,nan
# done with 927,205:-35,1
# done with 0,256:nan,nan
# done with 840,246:-34,6
# done with 843,247:-34,6
# done with 970,209:-35,2
# done with 923,209:-35,2
# done with 958,211:-35,2
# done with 0,256:nan,nan
# done with 983,211:-35,2
# done with 0,256:nan,nan
# done with 892,206:-35,2
# done with 0,256:nan,nan
# done with 805,252:-34,6
# done with 808,252:-35,6
# done with 935,211:-35,2
# done with 888,210:-35,2
# done with 923,213:-35,2
# done with 0,256:nan,nan
# done with
#  948,213:-35,2
# done with 0,256:nan,nan
# done with 857,207:-35,2
# done with 0,256:nan,nan
# done with 770,257:-35,6
# done with 773,257:-35,5
# done with 900,213:-35,2
# done with 853,212:-35,2
# done with 888,215:-35,3
# done with 0,256:nan,nan
# done with 913,215:-35,2
# done with 0,256:nan,nan
# done with 822,209:-35,2
# done with 0,256:nan,nan
# done with 735,262:-35,5
# done with 738,262:-35,5
# done with 865,215:-35,2
# done with 818,214:-35,2
# done with 853,217:-35,3
# done with 0,256:nan,nan
# done with
#  878,217:-35,3
# done with 0,256:nan,nan
# done with 787,211:-35,2
# done with 0,256:nan,nan
# done with 700,267:-35,5
# done with 703,266:-35,5
# done with 830,217:-35,3
# done with 783,216:-35,2
# done with 818,219:-35,3
# done with 0,256:nan,nan
# done with 843,219:-35,3
# done with 0,256:nan,nan
# done with 752,213:-35,3
# done with 0,256:nan,nan
# done with 665,271:-35,5
# done with 668,270:-35,4
# done with 795,219:-35,3
# done with 748,218:-35,3
# done with 783,221:-35,3
# done with 0,256:nan,nan
# done with
#  808,221:-35,3
# done with 0,256:nan,nan
# done with 717,215:-35,3
# done with 0,256:nan,nan
# done with 630,275:-35,4
# done with 633,273:-35,4
# done with 760,221:-35,3
# done with 713,220:-35,3
# done with 748,224:-35,3
# done with 0,256:nan,nan
# done with 773,223:-35,3
# done with 0,256:nan,nan
# done with 682,218:-35,3
# done with 0,256:nan,nan
# done with 595,278:-35,4
# done with 598,276:-35,4
# done with 725,224:-35,3
# done with 678,223:-35,3
# done with 713,227:-35,3
# done with 0,256:nan,nan
# done with
#  738,225:-35,3
# done with 0,256:nan,nan
# done with 647,221:-35,3
# done with 0,256:nan,nan
# done with 560,281:-35,4
# done with 563,279:-35,3
# done with 690,227:-35,3
# done with 643,226:-35,3
# done with 678,230:-35,3
# done with 0,256:nan,nan
# done with 703,228:-35,3
# done with 0,256:nan,nan
# done with 612,224:-35,4
# done with 0,256:nan,nan
# done with 525,284:-35,3
# done with 528,281:-35,3
# done with 655,230:-35,3
# done with 608,229:-35,3
# done with 643,233:-35,3
# done with 0,256:nan,nan
# done with
#  668,231:-35,3
# done with 0,256:nan,nan
# done with 577,227:-35,4
# done with 0,256:nan,nan
# done with 490,286:-35,3
# done with 493,283:-35,3
# done with 620,233:-35,3
# done with 573,232:-35,4
# done with 608,236:-35,3
# done with 0,256:nan,nan
# done with 633,234:-35,3
# done with 0,256:nan,nan
# done with 542,231:-35,4
# done with 0,256:nan,nan
# done with 455,288:-35,2
# done with 458,285:-35,2
# done with 585,236:-35,3
# done with 538,235:-35,4
# done with 573,239:-35,3
# done with 0,256:nan,nan
# done with
#  598,237:-35,3
# done with 0,256:nan,nan
# done with 507,235:-35,4
# done with 0,256:nan,nan
# done with 420,289:-35,2
# done with 423,286:-35,2
# done with 550,239:-35,4
# done with 503,238:-35,4
# done with 538,242:-35,4
# done with 0,256:nan,nan
# done with 563,240:-35,3
# done with 0,256:nan,nan
# done with 472,239:-35,4
# done with 0,256:nan,nan
# done with 385,290:-35,1
# done with 388,287:-35,1
# done with 515,242:-35,4
# done with 468,241:-35,4
# done with 503,245:-35,4
# done with 0,256:nan,nan
# done with
#  528,243:-35,3
# done with 0,256:nan,nan
# done with 437,243:-35,4
# done with 0,256:nan,nan
# done with 350,291:-35,1
# done with 353,288:-35,1
# done with 480,245:-35,4
# done with 433,244:-35,4
# done with 468,248:-35,4
# done with 0,256:nan,nan
# done with 493,246:-35,3
# done with 0,256:nan,nan
# done with 402,247:-35,4
# done with 0,256:nan,nan
# done with 315,291:-35,1
# done with 318,288:-35,1
# done with 445,248:-35,4
# done with 398,247:-35,4
# done with 433,251:-35,3
# done with 0,256:nan,nan
# done with
#  458,249:-35,3
# done with 0,256:nan,nan
# done with 367,251:-35,4
# done with 0,256:nan,nan
# done with 280,291:-35,0
# done with 283,288:-35,0
# done with 410,251:-35,3
# done with 363,250:-35,4
# done with 398,254:-35,3
# done with 0,256:nan,nan
# done with 423,252:-35,3
# done with 0,256:nan,nan
# done with 332,255:-35,4
# done with 0,256:nan,nan
# done with 245,290:-35,-0
# done with 248,288:-35,0
# done with 375,254:-35,3
# done with 328,253:-35,4
# done with 363,257:-35,3
# done with 0,256:nan,nan
# done with
#  388,255:-35,3
# done with 0,256:nan,nan
# done with 297,259:-35,4
# done with 0,256:nan,nan
# done with 210,289:-35,-0
# done with 213,287:-35,-0
# done with 340,257:-35,3
# done with 293,256:-35,4
# done with 328,260:-35,3
# done with 0,256:nan,nan
# done with 353,258:-35,3
# done with 0,256:nan,nan
# done with 262,263:-35,4
# done with 0,256:nan,nan
# done with 175,288:-35,-1
# done with 178,286:-35,-0
# done with 305,260:-35,3
# done with 258,259:-35,4
# done with 293,263:-35,3
# done with 0,256:nan,nan
# done with
#  318,261:-35,3
# done with 0,256:nan,nan
# done with 227,266:-35,4
# done with 0,256:nan,nan
# done with 140,287:-35,-1
# done with 143,285:-35,-1
# done with 270,263:-35,3
# done with 223,262:-35,4
# done with 258,266:-35,3
# done with 0,256:nan,nan
# done with 283,263:-35,3
# done with 0,256:nan,nan
# done with 192,269:-35,4
# done with 0,256:nan,nan
# done with 105,285:-35,-1
# done with 108,284:-35,-1
# done with 235,266:-35,3
# done with 188,265:-35,4
# done with 223,268:-35,3
# done with 0,256:nan,nan
# done with
#  248,265:-35,3
# done with 0,256:nan,nan
# done with 157,272:-35,4
# done with 0,256:nan,nan
# done with 70,283:-35,-1
# done with 73,282:-35,-1
# done with 200,268:-35,3
# done with 153,268:-35,4
# done with 188,270:-35,3
# done with 0,256:nan,nan
# done with 213,267:-35,3
# done with 0,256:nan,nan
# done with 122,275:-35,4
# done with 0,256:nan,nan
# done with 35,281:-34,-1
# done with 38,280:-34,-1
# done with 165,270:-35,3
# done with 118,271:-35,4
# done with 153,272:-35,3
# done with 0,256:nan,nan
# done with
#  178,269:-35,3
# done with 0,256:nan,nan
# done with 87,278:-35,4
# done with 0,256:nan,nan
# done with 1,279:-34,-2
# done with 3,278:-34,-1
# done with 130,272:-35,3
# done with 83,274:-35,3
# done with 118,274:-35,3
# done with 0,256:nan,nan
# done with 143,271:-35,3
# done with 0,256:nan,nan
# done with 52,281:-35,3
# done with 0,256:nan,nan
# done with 992,277:-33,-2
# done with 994,276:-33,-2
# done with 95,274:-35,3
# done with 48,277:-35,3
# done with 83,276:-35,2
# done with 0,256:nan,nan
# done with
#  108,273:-35,2
# done with 0,256:nan,nan
# done with 17,284:-35,3
# done with 0,256:nan,nan
# done with 957,275:-35,-2
# done with 959,274:-35,-2
# done with 60,276:-35,3
# done with 13,280:-35,3
# done with 48,278:-35,2
# done with 0,256:nan,nan
# done with 73,275:-35,2
# done with 0,256:nan,nan
# done with 1007,287:-35,3
# done with 0,256:nan,nan
# done with 922,273:-35,-2
# done with 924,272:-35,-1
# done with 25,278:-35,2
# done with 1003,283:-35,3
# done with 13,280:-35,2
# done with 0,256:nan,nan
# done with
#  38,277:-35,2
# done with 0,256:nan,nan
# done with 972,289:-35,3
# done with 0,256:nan,nan
# done with 887,271:-35,-1
# done with 889,270:-35,-1
# done with 1015,280:-35,2
# done with 968,285:-35,3
# done with 1003,282:-35,2
# done with 0,256:nan,nan
# done with 3,278:-35,2
# done with 0,256:nan,nan
# done with 937,291:-35,3
# done with 0,256:nan,nan
# done with 852,269:-35,-1
# done with 854,269:-35,-1
# done with 980,282:-35,2
# done with 933,287:-35,3
# done with 968,283:-35,2
# done with 0,256:nan,nan
# done with
#  993,279:-35,2
# done with 0,256:nan,nan
# done with 902,293:-35,2
# done with 0,256:nan,nan
# done with 817,268:-35,-1
# done with 819,268:-35,-1
# done with 945,284:-35,2
# done with 898,289:-35,3
# done with 933,284:-35,2
# done with 0,256:nan,nan
# done with 958,280:-35,2
# done with 0,256:nan,nan
# done with 867,295:-35,2
# done with 0,256:nan,nan
# done with 782,267:-35,-1
# done with 784,267:-35,-0
# done with 910,285:-35,2
# done with 863,291:-35,2
# done with 898,285:-35,2
# done with 0,256:nan,nan
# done with
#  923,281:-35,2
# done with 0,256:nan,nan
# done with 832,297:-35,2
# done with 0,256:nan,nan
# done with 747,266:-35,-0
# done with 749,266:-35,-0
# done with 875,286:-35,2
# done with 828,293:-35,2
# done with 863,286:-35,2
# done with 0,256:nan,nan
# done with 888,282:-35,2
# done with 0,256:nan,nan
# done with 797,298:-35,2
# done with 0,256:nan,nan
# done with 712,265:-35,-0
# done with 714,266:-35,0
# done with 840,287:-35,2
# done with 793,295:-35,2
# done with 828,287:-35,2
# done with 0,256:nan,nan
# done with
#  853,283:-35,2
# done with 0,256:nan,nan
# done with 762,299:-35,2
# done with 0,256:nan,nan
# done with 677,265:-35,0
# done with 679,266:-35,0
# done with 805,288:-35,2
# done with 758,296:-35,2
# done with 793,288:-35,1
# done with 0,256:nan,nan
# done with 818,284:-35,1
# done with 0,256:nan,nan
# done with 727,300:-35,1
# done with 0,256:nan,nan
# done with 642,265:-35,0
# done with 644,266:-35,1
# done with 770,289:-35,2
# done with 723,297:-35,2
# done with 758,289:-35,1
# done with 0,256:nan,nan
# done with
#  783,285:-35,1
# done with 0,256:nan,nan
# done with 692,301:-35,1
# done with 0,256:nan,nan
# done with 607,265:-35,1
# done with 609,266:-35,1
# done with 735,290:-35,1
# done with 688,298:-35,1
# done with 723,290:-35,1
# done with 0,256:nan,nan
# done with 748,286:-35,1
# done with 0,256:nan,nan
# done with 657,302:-35,1
# done with 0,256:nan,nan
# done with 572,265:-35,1
# done with 574,267:-35,1
# done with 700,291:-35,1
# done with 653,299:-35,1
# done with 688,291:-35,1
# done with 0,256:nan,nan
# done with
#  713,287:-35,1
# done with 0,256:nan,nan
# done with 622,302:-35,1
# done with 0,256:nan,nan
# done with 537,266:-35,1
# done with 539,268:-35,1
# done with 665,292:-35,1
# done with 618,300:-35,1
# done with 653,292:-35,1
# done with 0,256:nan,nan
# done with 678,288:-35,1
# done with 0,256:nan,nan
# done with 587,302:-35,1
# done with 0,256:nan,nan
# done with 502,267:-35,1
# done with 504,269:-35,2
# done with 630,293:-35,1
# done with 583,301:-35,1
# done with 618,293:-35,1
# done with 0,256:nan,nan
# done with
#  643,289:-35,1
# done with 0,256:nan,nan
# done with 552,302:-35,1
# done with 0,256:nan,nan
# done with 467,268:-35,2
# done with 469,270:-35,2
# done with 595,294:-35,1
# done with 548,301:-35,1
# done with 583,294:-35,1
# done with 0,256:nan,nan
# done with 608,290:-35,1
# done with 0,256:nan,nan
# done with 517,302:-35,0
# done with 0,256:nan,nan
# done with 432,269:-35,2
# done with 434,271:-35,2
# done with 560,295:-35,1
# done with 513,301:-35,1
# done with 548,294:-35,1
# done with 0,256:nan,nan
# done with
#  573,291:-35,1
# done with 0,256:nan,nan
# done with 482,302:-35,0
# done with 0,256:nan,nan
# done with 397,270:-35,2
# done with 399,272:-35,2
# done with 525,295:-35,1
# done with 478,301:-35,1
# done with 513,294:-35,1
# done with 0,256:nan,nan
# done with 538,292:-35,1
# done with 0,256:nan,nan
# done with 447,302:-35,0
# done with 0,256:nan,nan
# done with 362,271:-35,2
# done with 364,273:-35,2
# done with 490,295:-35,1
# done with 443,301:-35,0
# done with 478,294:-35,1
# done with 0,256:nan,nan
# done with
#  503,293:-35,1
# done with 0,256:nan,nan
# done with 412,301:-35,-0
# done with 0,256:nan,nan
# done with 327,273:-35,2
# done with 329,274:-35,2
# done with 455,295:-35,1
# done with 408,301:-35,0
# done with 443,294:-35,1
# done with 0,256:nan,nan
# done with 468,293:-35,1
# done with 0,256:nan,nan
# done with 377,300:-35,-0
# done with 0,256:nan,nan
# done with 292,275:-35,2
# done with 294,275:-35,2
# done with 420,295:-35,0
# done with 373,300:-35,-0
# done with 408,294:-35,0
# done with 0,256:nan,nan
# done with
#  433,293:-35,1
# done with 0,256:nan,nan
# done with 342,299:-35,-1
# done with 0,256:nan,nan
# done with 257,277:-35,2
# done with 259,277:-35,2
# done with 385,295:-35,0
# done with 338,299:-35,-0
# done with 373,294:-35,0
# done with 0,256:nan,nan
# done with 398,293:-35,1
# done with 0,256:nan,nan
# done with 307,298:-35,-1
# done with 0,256:nan,nan
# done with 222,279:-35,2
# done with 224,279:-35,2
# done with 350,295:-35,0
# done with 303,298:-35,-0
# done with 338,294:-35,0
# done with 0,256:nan,nan
# done with
#  363,293:-35,0
# done with 0,256:nan,nan
# done with 272,297:-35,-1
# done with 0,256:nan,nan
# done with 187,281:-35,2
# done with 189,281:-35,2
# done with 315,294:-35,-0
# done with 268,297:-35,-1
# done with 303,293:-35,-0
# done with 0,256:nan,nan
# done with 328,293:-35,0
# done with 0,256:nan,nan
# done with 237,295:-35,-1
# done with 0,256:nan,nan
# done with 152,283:-35,2
# done with 154,283:-35,2
# done with 280,293:-35,-0
# done with 233,296:-35,-1
# done with 268,292:-35,-0
# done with 0,256:nan,nan
# done with
#  293,293:-35,0
# done with 0,256:nan,nan
# done with 202,293:-35,-1
# done with 0,256:nan,nan
# done with 117,285:-35,2
# done with 119,284:-35,2
# done with 245,292:-35,-0
# done with 198,295:-35,-1
# done with 233,291:-35,-0
# done with 0,256:nan,nan
# done with 258,292:-35,-0
# done with 0,256:nan,nan
# done with 167,291:-35,-1
# done with 0,256:nan,nan
# done with 82,287:-35,2
# done with 84,285:-35,2
# done with 210,291:-35,-0
# done with 163,293:-35,-1
# done with 198,290:-35,-0
# done with 0,256:nan,nan
# done with
#  223,291:-35,-0
# done with 0,256:nan,nan
# done with 132,289:-35,-1
# done with 0,256:nan,nan
# done with 47,288:-34,2
# done with 49,286:-35,2
# done with 175,290:-35,-1
# done with 128,291:-35,-1
# done with 163,289:-35,-0
# done with 0,256:nan,nan
# done with 188,290:-35,-0
# done with 0,256:nan,nan
# done with 97,287:-35,-2
# done with 0,256:nan,nan
# done with 13,289:-34,2
# done with 14,287:-34,2
# done with 140,289:-35,-1
# done with 93,289:-35,-1
# done with 128,288:-35,-1
# done with 0,256:nan,nan
# done with
#  153,289:-35,-0
# done with 0,256:nan,nan
# done with 62,285:-35,-2
# done with 0,256:nan,nan
# done with 1004,290:-33,2
# done with 1005,288:-34,2
# done with 105,288:-35,-1
# done with 58,287:-35,-1
# done with 93,287:-35,-1
# done with 0,256:nan,nan
# done with 118,288:-35,-1
# done with 0,256:nan,nan
# done with 27,283:-35,-2
# done with 0,256:nan,nan
# done with 969,291:-35,2
# done with 970,289:-35,2
# done with 70,287:-35,-1
# done with 23,285:-35,-2
# done with 58,286:-35,-1
# done with 0,256:nan,nan
# done with
#  83,287:-35,-1
# done with 0,256:nan,nan
# done with 1017,281:-35,-2
# done with 0,256:nan,nan
# done with 934,292:-35,2
# done with 935,290:-35,2
# done with 35,285:-35,-1
# done with 1013,283:-35,-2
# done with 23,284:-35,-1
# done with 0,256:nan,nan
# done with 48,286:-35,-1
# done with 0,256:nan,nan
# done with 982,279:-35,-2
# done with 0,256:nan,nan
# done with 899,293:-35,1
# done with 900,291:-35,2
# done with 0,283:-35,-1
# done with 978,281:-35,-2
# done with 1013,282:-35,-1
# done with 0,256:nan,nan
# done with
#  13,284:-35,-1
# done with 0,256:nan,nan
# done with 947,277:-35,-1
# done with 0,256:nan,nan
# done with 864,294:-35,1
# done with 865,292:-35,1
# done with 990,281:-35,-1
# done with 943,279:-35,-1
# done with 978,280:-35,-1
# done with 0,256:nan,nan
# done with 1003,282:-35,-1
# done with 0,256:nan,nan
# done with 912,275:-35,-1
# done with 0,256:nan,nan
# done with 829,295:-35,1
# done with 830,293:-35,1
# done with 955,279:-35,-1
# done with 908,277:-35,-1
# done with 943,279:-35,-1
# done with 0,256:nan,nan
# done with
#  968,280:-35,-1
# done with 0,256:nan,nan
# done with 877,273:-35,-1
# done with 0,256:nan,nan
# done with 794,295:-35,1
# done with 795,293:-35,1
# done with 920,277:-35,-1
# done with 873,275:-35,-1
# done with 908,278:-35,-1
# done with 0,256:nan,nan
# done with 933,278:-35,-1
# done with 0,256:nan,nan
# done with 842,271:-35,-1
# done with 0,256:nan,nan
# done with 759,295:-35,1
# done with 760,293:-35,1
# done with 885,275:-35,-1
# done with 838,273:-35,-1
# done with 873,277:-35,-1
# done with 0,256:nan,nan
# done with
#  898,276:-35,-1
# done with 0,256:nan,nan
# done with 807,270:-35,-1
# done with 0,256:nan,nan
# done with 724,295:-35,0
# done with 725,293:-35,1
# done with 850,274:-35,-1
# done with 803,271:-35,-1
# done with 838,276:-35,-1
# done with 0,256:nan,nan
# done with 863,275:-35,-1
# done with 0,256:nan,nan
# done with 772,269:-35,-1
# done with 0,256:nan,nan
# done with 689,295:-35,0
# done with 690,293:-35,0
# done with 815,273:-35,-1
# done with 768,270:-35,-1
# done with 803,275:-35,-1
# done with 0,256:nan,nan
# done with
#  828,274:-35,-1
# done with 0,256:nan,nan
# done with 737,268:-35,-1
# done with 0,256:nan,nan
# done with 654,294:-35,-0
# done with 655,293:-35,0
# done with 780,272:-35,-1
# done with 733,269:-35,-1
# done with 768,274:-35,-1
# done with 0,256:nan,nan
# done with 793,273:-35,-1
# done with 0,256:nan,nan
# done with 702,267:-35,-1
# done with 0,256:nan,nan
# done with 619,293:-35,-0
# done with 620,292:-35,-0
# done with 745,271:-35,-1
# done with 698,268:-35,-1
# done with 733,273:-35,-1
# done with 0,256:nan,nan
# done with
#  758,272:-35,-1
# done with 0,256:nan,nan
# done with 667,266:-35,-0
# done with 0,256:nan,nan
# done with 584,292:-35,-0
# done with 585,291:-35,-0
# done with 710,270:-35,-1
# done with 663,267:-35,-1
# done with 698,272:-35,-1
# done with 0,256:nan,nan
# done with 723,271:-35,-1
# done with 0,256:nan,nan
# done with 632,265:-35,-0
# done with 0,256:nan,nan
# done with 549,291:-35,-1
# done with 550,290:-35,-0
# done with 675,269:-35,-1
# done with 628,266:-35,-0
# done with 663,271:-35,-1
# done with 0,256:nan,nan
# done with
#  688,270:-35,-1
# done with 0,256:nan,nan
# done with 597,264:-35,-0
# done with 0,256:nan,nan
# done with 514,290:-35,-1
# done with 515,289:-35,-1
# done with 640,268:-35,-1
# done with 593,265:-35,-0
# done with 628,270:-35,-0
# done with 0,256:nan,nan
# done with 653,269:-35,-1
# done with 0,256:nan,nan
# done with 562,263:-35,-0
# done with 0,256:nan,nan
# done with 479,288:-35,-1
# done with 480,288:-35,-1
# done with 605,267:-35,-0
# done with 558,264:-35,-0
# done with 593,269:-35,-0
# done with 0,256:nan,nan
# done with
#  618,268:-35,-0
# done with 0,256:nan,nan
# done with 527,262:-35,-0
# done with 0,256:nan,nan
# done with 444,286:-35,-1
# done with 445,286:-35,-1
# done with 570,266:-35,-0
# done with 523,263:-35,-0
# done with 558,268:-35,-0
# done with 0,256:nan,nan
# done with 583,267:-35,-0
# done with 0,256:nan,nan
# done with 492,262:-35,0
# done with 0,256:nan,nan
# done with 409,284:-35,-1
# done with 410,284:-35,-1
# done with 535,265:-35,-0
# done with 488,262:-35,-0
# done with 523,267:-35,-0
# done with 0,256:nan,nan
# done with
#  548,266:-35,-0
# done with 0,256:nan,nan
# done with 457,262:-35,0
# done with 0,256:nan,nan
# done with 374,282:-35,-2
# done with 375,282:-35,-1
# done with 500,264:-35,-0
# done with 453,261:-35,-0
# done with 488,266:-35,-0
# done with 0,256:nan,nan
# done with 513,265:-35,-0
# done with 0,256:nan,nan
# done with 422,262:-35,0
# done with 0,256:nan,nan
# done with 339,280:-35,-2
# done with 340,280:-35,-2
# done with 465,263:-35,-0
# done with 418,260:-35,-0
# done with 453,265:-35,-0
# done with 0,256:nan,nan
# done with
#  478,264:-35,-0
# done with 0,256:nan,nan
# done with 387,262:-35,0
# done with 0,256:nan,nan
# done with 304,278:-35,-2
# done with 305,278:-35,-2
# done with 430,262:-35,-0
# done with 383,259:-35,-0
# done with 418,264:-35,-0
# done with 0,256:nan,nan
# done with 443,263:-35,-0
# done with 0,256:nan,nan
# done with 352,262:-35,0
# done with 0,256:nan,nan
# done with 269,275:-35,-2
# done with 270,276:-35,-2
# done with 395,261:-35,-0
# done with 348,258:-35,-0
# done with 383,263:-35,-0
# done with 0,256:nan,nan
# done with
#  408,262:-35,-0
# done with 0,256:nan,nan
# done with 317,262:-35,0
# done with 0,256:nan,nan
# done with 234,272:-35,-2
# done with 235,274:-35,-2
# done with 360,260:-35,-0
# done with 313,258:-35,0
# done with 348,262:-35,-0
# done with 0,256:nan,nan
# done with 373,261:-35,-0
# done with 0,256:nan,nan
# done with 282,262:-35,0
# done with 0,256:nan,nan
# done with 199,269:-35,-2
# done with 200,271:-35,-2
# done with 325,259:-35,-0
# done with 278,258:-35,0
# done with 313,261:-35,-0
# done with 0,256:nan,nan
# done with
#  338,260:-35,-0
# done with 0,256:nan,nan
# done with 247,262:-35,0
# done with 0,256:nan,nan
# done with 164,266:-35,-2
# done with 165,268:-35,-2
# done with 290,258:-35,-0
# done with 243,258:-35,0
# done with 278,260:-35,-0
# done with 0,256:nan,nan
# done with 303,259:-35,-0
# done with 0,256:nan,nan
# done with 212,262:-35,0
# done with 0,256:nan,nan
# done with 129,263:-35,-2
# done with 130,265:-35,-2
# done with 255,257:-35,-0
# done with 208,258:-35,0
# done with 243,259:-35,-0
# done with 0,256:nan,nan
# done with
#  268,258:-35,-0
# done with 0,256:nan,nan
# done with 177,262:-35,0
# done with 0,256:nan,nan
# done with 94,260:-35,-2
# done with 95,262:-35,-2
# done with 220,256:-35,-0
# done with 173,258:-35,0
# done with 208,258:-35,-0
# done with 0,256:nan,nan
# done with 233,257:-35,-0
# done with 0,256:nan,nan
# done with 142,261:-35,-0
# done with 0,256:nan,nan
# done with 59,257:-35,-2
# done with 60,259:-35,-2
# done with 185,255:-35,-0
# done with 138,258:-35,0
# done with 173,257:-35,-0
# done with 0,256:nan,nan
# done with
#  198,256:-35,-0
# done with 0,256:nan,nan
# done with 107,260:-35,-0
# done with 0,256:nan,nan
# done with 24,254:-34,-2
# done with 25,256:-34,-2
# done with 150,254:-35,-0
# done with 103,258:-35,0
# done with 138,256:-35,-0
# done with 0,256:nan,nan
# done with 163,255:-35,-0
# done with 0,256:nan,nan
# done with 72,259:-35,-0
# done with 0,256:nan,nan
# done with 1015,251:-34,-2
# done with 1016,253:-34,-2
# done with 115,253:-35,-0
# done with 68,258:-35,0
# done with 103,255:-35,-0
# done with 0,256:nan,nan
# done with
#  128,254:-35,-0
# done with 0,256:nan,nan
# done with 37,258:-35,-0
# done with 0,256:nan,nan
# done with 980,248:-35,-3
# done with 981,250:-35,-3
# done with 80,252:-35,-0
# done with 33,258:-35,0
# done with 68,254:-35,-0
# done with 0,256:nan,nan
# done with 93,253:-35,-0
# done with 0,256:nan,nan
# done with 2,257:-35,-0
# done with 0,256:nan,nan
# done with 945,245:-35,-3
# done with 946,247:-35,-3
# done with 45,252:-35,0
# done with 1023,257:-35,-0
# done with 33,253:-35,-0
# done with 0,256:nan,nan
# done with
#  58,252:-35,-0
# done with 0,256:nan,nan
# done with 992,256:-35,-0
# done with 0,256:nan,nan
# done with 910,242:-35,-2
# done with 911,244:-35,-2
# done with 10,252:-35,0
# done with 988,256:-35,-0
# done with 1023,252:-35,-0
# done with 0,256:nan,nan
# done with 23,251:-35,-0
# done with 0,256:nan,nan
# done with 957,255:-35,-0
# done with 0,256:nan,nan
# done with 875,239:-35,-2
# done with 876,241:-35,-2
# done with 1000,252:-35,0
# done with 953,255:-35,-0
# done with 988,251:-35,-0
# done with 0,256:nan,nan
# done with
#  1013,250:-35,-0
# done with 0,256:nan,nan
# done with 922,254:-35,-0
# done with 0,256:nan,nan
# done with 840,236:-35,-2
# done with 841,238:-35,-2
# done with 965,251:-35,-0
# done with 918,254:-35,-0
# done with 953,250:-35,-0
# done with 0,256:nan,nan
# done with 978,249:-35,-0
# done with 0,256:nan,nan
# done with 887,253:-35,-1
# done with 0,256:nan,nan
# done with 805,234:-35,-2
# done with 806,235:-35,-2
# done with 930,250:-35,-0
# done with 883,253:-35,-0
# done with 918,249:-35,-0
# done with 0,256:nan,nan
# done with
#  943,248:-35,-0
# done with 0,256:nan,nan
# done with 852,252:-35,-1
# done with 0,256:nan,nan
# done with 770,232:-35,-2
# done with 771,233:-35,-2
# done with 895,249:-35,-0
# done with 848,252:-35,-1
# done with 883,248:-35,-1
# done with 0,256:nan,nan
# done with 908,247:-35,-0
# done with 0,256:nan,nan
# done with 817,251:-35,-1
# done with 0,256:nan,nan
# done with 735,230:-35,-2
# done with 736,231:-35,-2
# done with 860,248:-35,-0
# done with 813,251:-35,-1
# done with 848,247:-35,-1
# done with 0,256:nan,nan
# done with
#  873,246:-35,-0
# done with 0,256:nan,nan
# done with 782,250:-35,-1
# done with 0,256:nan,nan
# done with 700,228:-35,-1
# done with 701,229:-35,-2
# done with 825,247:-35,-0
# done with 778,250:-35,-1
# done with 813,246:-35,-1
# done with 0,256:nan,nan
# done with 838,245:-35,-0
# done with 0,256:nan,nan
# done with 747,249:-35,-1
# done with 0,256:nan,nan
# done with 665,226:-35,-1
# done with 666,227:-35,-1
# done with 790,246:-35,-0
# done with 743,249:-35,-1
# done with 778,245:-35,-1
# done with 0,256:nan,nan
# done with
#  803,244:-35,-0
# done with 0,256:nan,nan
# done with 712,248:-35,-1
# done with 0,256:nan,nan
# done with 630,224:-35,-1
# done with 631,225:-35,-1
# done with 755,245:-35,-1
# done with 708,248:-35,-1
# done with 743,244:-35,-1
# done with 0,256:nan,nan
# done with 768,243:-35,-0
# done with 0,256:nan,nan
# done with 677,246:-35,-1
# done with 0,256:nan,nan
# done with 595,223:-35,-1
# done with 596,223:-35,-1
# done with 720,244:-35,-1
# done with 673,246:-35,-1
# done with 708,243:-35,-1
# done with 0,256:nan,nan
# done with
#  733,242:-35,-1
# done with 0,256:nan,nan
# done with 642,244:-35,-1
# done with 0,256:nan,nan
# done with 560,222:-35,-1
# done with 561,221:-35,-1
# done with 685,243:-35,-1
# done with 638,244:-35,-1
# done with 673,242:-35,-1
# done with 0,256:nan,nan
# done with 698,241:-35,-1
# done with 0,256:nan,nan
# done with 607,242:-35,-1
# done with 0,256:nan,nan
# done with 525,221:-35,-1
# done with 526,220:-35,-1
# done with 650,242:-35,-1
# done with 603,242:-35,-1
# done with 638,241:-35,-1
# done with 0,256:nan,nan
# done with
#  663,240:-35,-1
# done with 0,256:nan,nan
# done with 572,240:-35,-1
# done with 0,256:nan,nan
# done with 490,220:-35,-1
# done with 491,219:-35,-1
# done with 615,241:-35,-1
# done with 568,240:-35,-1
# done with 603,240:-35,-1
# done with 0,256:nan,nan
# done with 628,239:-35,-1
# done with 0,256:nan,nan
# done with 537,238:-35,-1
# done with 0,256:nan,nan
# done with 455,219:-35,-0
# done with 456,218:-35,-0
# done with 580,240:-35,-1
# done with 533,238:-35,-1
# done with 568,239:-35,-1
# done with 0,256:nan,nan
# done with
#  593,238:-35,-1
# done with 0,256:nan,nan
# done with 502,236:-35,-1
# done with 0,256:nan,nan
# done with 420,218:-35,-0
# done with 421,217:-35,-0
# done with 545,239:-35,-1
# done with 498,236:-35,-1
# done with 533,237:-35,-1
# done with 0,256:nan,nan
# done with 558,237:-35,-1
# done with 0,256:nan,nan
# done with 467,234:-35,-1
# done with 0,256:nan,nan
# done with 385,218:-35,0
# done with 386,217:-35,0
# done with 510,238:-35,-1
# done with 463,234:-35,-1
# done with 498,235:-35,-1
# done with 0,256:nan,nan
# done with
#  523,236:-35,-1
# done with 0,256:nan,nan
# done with 432,232:-35,-1
# done with 0,256:nan,nan
# done with 350,218:-35,0
# done with 351,217:-35,0
# done with 475,236:-35,-1
# done with 428,232:-35,-1
# done with 463,234:-35,-1
# done with 0,256:nan,nan
# done with 488,235:-35,-1
# done with 0,256:nan,nan
# done with 397,230:-35,-1
# done with 0,256:nan,nan
# done with 315,218:-35,1
# done with 316,217:-35,0
# done with 440,235:-35,-1
# done with 393,230:-35,-1
# done with 428,233:-35,-1
# done with 0,256:nan,nan
# done with
#  453,234:-35,-1
# done with 0,256:nan,nan
# done with 362,228:-35,-1
# done with 0,256:nan,nan
# done with 280,218:-35,1
# done with 281,217:-35,1
# done with 405,234:-35,-1
# done with 358,229:-35,-1
# done with 393,232:-35,-1
# done with 0,256:nan,nan
# done with 418,233:-35,-1
# done with 0,256:nan,nan
# done with 327,227:-35,-1
# done with 0,256:nan,nan
# done with 245,218:-35,1
# done with 246,217:-35,1
# done with 370,233:-35,-1
# done with 323,228:-35,-1
# done with 358,231:-35,-1
# done with 0,256:nan,nan
# done with
#  383,232:-35,-1
# done with 0,256:nan,nan
# done with 292,226:-35,-1
# done with 0,256:nan,nan
# done with 210,219:-35,1
# done with 211,218:-35,1
# done with 335,232:-35,-1
# done with 288,227:-35,-1
# done with 323,230:-35,-1
# done with 0,256:nan,nan
# done with 348,231:-35,-1
# done with 0,256:nan,nan
# done with 257,225:-35,-1
# done with 0,256:nan,nan
# done with 175,220:-35,1
# done with 176,219:-35,1
# done with 300,231:-35,-1
# done with 253,226:-35,-1
# done with 288,229:-35,-1
# done with 0,256:nan,nan
# done with
#  313,230:-35,-1
# done with 0,256:nan,nan
# done with 222,224:-35,-1
# done with 0,256:nan,nan
# done with 140,221:-35,1
# done with 141,220:-35,1
# done with 265,230:-35,-1
# done with 218,225:-35,-0
# done with 253,228:-35,-1
# done with 0,256:nan,nan
# done with 278,229:-35,-0
# done with 0,256:nan,nan
# done with 187,223:-35,-0
# done with 0,256:nan,nan
# done with 105,222:-35,1
# done with 106,221:-35,2
# done with 230,229:-35,-1
# done with 183,224:-35,-0
# done with 218,227:-35,-0
# done with 0,256:nan,nan
# done with
#  243,228:-35,-0
# done with 0,256:nan,nan
# done with 152,222:-35,-0
# done with 0,256:nan,nan
# done with 70,223:-35,2
# done with 71,222:-35,2
# done with 195,228:-35,-0
# done with 148,223:-35,-0
# done with 183,226:-35,-0
# done with 0,256:nan,nan
# done with 208,227:-35,-0
# done with 0,256:nan,nan
# done with 117,221:-35,-0
# done with 0,256:nan,nan
# done with 35,224:-34,2
# done with 36,223:-34,2
# done with 160,227:-35,-0
# done with 113,222:-35,-0
# done with 148,225:-35,-0
# done with 0,256:nan,nan
# done with
#  173,226:-35,-0
# done with 0,256:nan,nan
# done with 82,220:-35,-0
# done with 0,256:nan,nan
# done with 1,225:-34,2
# done with 1,224:-34,2
# done with 125,226:-35,-0
# done with 78,221:-35,-0
# done with 113,224:-35,-0
# done with 0,256:nan,nan
# done with 138,225:-35,-0
# done with 0,256:nan,nan
# done with 47,220:-35,0
# done with 0,256:nan,nan
# done with 992,226:-33,2
# done with 992,226:-33,2
# done with 90,225:-35,-0
# done with 43,221:-35,0
# done with 78,223:-35,-0
# done with 0,256:nan,nan
# done with
#  103,224:-35,-0
# done with 0,256:nan,nan
# done with 12,220:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 957,228:-35,2
# done with 55,224:-35,-0
# done with 8,221:-35,0
# done with 43,223:-35,0
# done with 0,256:nan,nan
# done with 68,224:-35,0
# done with 0,256:nan,nan
# done with 1002,220:-35,1
# ...
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 202,253:-35,0
# done with 315,250:-35,1
# done with 268,253:-35,0
# done with 303,251:-35,0
# done with 0,256:nan,nan
# done with 328,250:-35,1
# done with 0,256:nan,nan
# done with 237,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 167,253:-35,0
# done with 280,250:-35,1
# done with 233,253:-35,0
# done with 268,251:-35,1
# done with 0,256:nan,nan
# done with
#  293,250:-35,1
# done with 0,256:nan,nan
# done with 202,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 132,253:-35,0
# done with 245,250:-35,1
# done with 198,253:-35,0
# done with 233,251:-35,1
# done with 0,256:nan,nan
# done with 258,250:-35,1
# done with 0,256:nan,nan
# done with 167,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 97,253:-35,0
# done with 210,250:-35,1
# done with 163,253:-35,0
# done with 198,251:-35,1
# done with 0,256:nan,nan
# done with
#  223,250:-35,1
# done with 0,256:nan,nan
# done with 132,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 62,253:-35,0
# done with 175,250:-35,1
# done with 128,253:-35,0
# done with 163,251:-35,1
# done with 0,256:nan,nan
# done with 188,250:-35,1
# done with 0,256:nan,nan
# done with 97,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 27,253:-35,0
# done with 140,250:-35,1
# done with 93,253:-35,0
# done with 128,251:-35,1
# done with 0,256:nan,nan
# done with
#  153,250:-35,1
# done with 0,256:nan,nan
# done with 62,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 1017,253:-34,0
# done with 105,250:-35,1
# done with 58,253:-35,0
# done with 93,251:-35,1
# done with 0,256:nan,nan
# done with 118,250:-35,1
# done with 0,256:nan,nan
# done with 27,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 982,253:-35,0
# done with 70,250:-35,1
# done with 23,253:-35,0
# done with 58,251:-35,1
# done with 0,256:nan,nan
# done with
#  83,250:-35,1
# done with 0,256:nan,nan
# done with 1017,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 947,253:-35,0
# done with 35,250:-35,1
# done with 1013,253:-35,0
# done with 23,251:-35,1
# done with 0,256:nan,nan
# done with 48,250:-35,1
# done with 0,256:nan,nan
# done with 982,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 912,253:-35,0
# done with 0,250:-35,1
# done with 978,253:-35,0
# done with 1013,251:-35,1
# done with 0,256:nan,nan
# done with
#  13,250:-35,1
# done with 0,256:nan,nan
# done with 947,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 877,253:-35,0
# done with 990,250:-35,1
# done with 943,253:-35,0
# done with 978,251:-35,1
# done with 0,256:nan,nan
# done with 1003,250:-35,1
# done with 0,256:nan,nan
# done with 912,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 842,253:-35,0
# done with 955,250:-35,1
# done with 908,253:-35,0
# done with 943,251:-35,1
# done with 0,256:nan,nan
# done with
#  968,250:-35,1
# done with 0,256:nan,nan
# done with 877,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 807,253:-35,0
# done with 920,250:-35,1
# done with 873,253:-35,0
# done with 908,251:-35,1
# done with 0,256:nan,nan
# done with 933,250:-35,1
# done with 0,256:nan,nan
# done with 842,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 772,253:-35,0
# done with 885,250:-35,1
# done with 838,253:-35,0
# done with 873,251:-35,1
# done with 0,256:nan,nan
# done with
#  898,250:-35,1
# done with 0,256:nan,nan
# done with 807,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 737,253:-35,0
# done with 850,250:-35,1
# done with 803,253:-35,0
# done with 838,251:-35,1
# done with 0,256:nan,nan
# done with 863,250:-35,1
# done with 0,256:nan,nan
# done with 772,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 702,253:-35,0
# done with 815,250:-35,1
# done with 768,253:-35,0
# done with 803,251:-35,1
# done with 0,256:nan,nan
# done with
#  828,250:-35,1
# done with 0,256:nan,nan
# done with 737,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 667,253:-35,0
# done with 780,250:-35,1
# done with 733,253:-35,0
# done with 768,251:-35,1
# done with 0,256:nan,nan
# done with 793,250:-35,1
# done with 0,256:nan,nan
# done with 702,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 632,253:-35,0
# done with 745,250:-35,1
# done with 698,253:-35,0
# done with 733,251:-35,1
# done with 0,256:nan,nan
# done with
#  758,250:-35,1
# done with 0,256:nan,nan
# done with 667,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 597,253:-35,0
# done with 710,250:-35,1
# done with 663,253:-35,0
# done with 698,251:-35,1
# done with 0,256:nan,nan
# done with 723,250:-35,1
# done with 0,256:nan,nan
# done with 632,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 562,253:-35,0
# done with 675,250:-35,1
# done with 628,253:-35,0
# done with 663,251:-35,1
# done with 0,256:nan,nan
# done with
#  688,250:-35,1
# done with 0,256:nan,nan
# done with 597,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 527,253:-35,0
# done with 640,250:-35,1
# done with 593,253:-35,0
# done with 628,251:-35,1
# done with 0,256:nan,nan
# done with 653,250:-35,1
# done with 0,256:nan,nan
# done with 562,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 492,253:-35,0
# done with 605,250:-35,1
# done with 558,253:-35,0
# done with 593,251:-35,1
# done with 0,256:nan,nan
# done with
#  618,250:-35,1
# done with 0,256:nan,nan
# done with 527,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 457,253:-35,0
# done with 570,250:-35,1
# done with 523,253:-35,0
# done with 558,251:-35,1
# done with 0,256:nan,nan
# done with 583,250:-35,1
# done with 0,256:nan,nan
# done with 492,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 422,253:-35,0
# done with 535,250:-35,1
# done with 488,253:-35,0
# done with 523,251:-35,1
# done with 0,256:nan,nan
# done with
#  548,250:-35,1
# done with 0,256:nan,nan
# done with 457,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 387,253:-35,0
# done with 500,250:-35,1
# done with 453,253:-35,0
# done with 488,251:-35,1
# done with 0,256:nan,nan
# done with 513,250:-35,1
# done with 0,256:nan,nan
# done with 422,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 352,253:-35,0
# done with 465,250:-35,1
# done with 418,253:-35,0
# done with 453,251:-35,1
# done with 0,256:nan,nan
# done with
#  478,250:-35,1
# done with 0,256:nan,nan
# done with 387,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 317,253:-35,0
# done with 430,250:-35,1
# done with 383,253:-35,0
# done with 418,251:-35,0
# done with 0,256:nan,nan
# done with 443,250:-35,1
# done with 0,256:nan,nan
# done with 352,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 282,253:-35,0
# done with 395,250:-35,1
# done with 348,253:-35,0
# done with 383,251:-35,0
# done with 0,256:nan,nan
# done with
#  408,250:-35,1
# done with 0,256:nan,nan
# done with 317,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 247,253:-35,0
# done with 360,250:-35,1
# done with 313,253:-35,0
# done with 348,251:-35,0
# done with 0,256:nan,nan
# done with 373,250:-35,1
# done with 0,256:nan,nan
# done with 282,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 212,253:-35,0
# done with 325,250:-35,1
# done with 278,253:-35,0
# done with 313,251:-35,0
# done with 0,256:nan,nan
# done with
#  338,250:-35,1
# done with 0,256:nan,nan
# done with 247,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 177,253:-35,0
# done with 290,250:-35,1
# done with 243,253:-35,0
# done with 278,251:-35,0
# done with 0,256:nan,nan
# done with 303,250:-35,1
# done with 0,256:nan,nan
# done with 212,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 142,253:-35,0
# done with 255,250:-35,1
# done with 208,253:-35,0
# done with 243,251:-35,1
# done with 0,256:nan,nan
# done with
#  268,250:-35,1
# done with 0,256:nan,nan
# done with 177,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 107,253:-35,0
# done with 220,250:-35,1
# done with 173,253:-35,0
# done with 208,251:-35,1
# done with 0,256:nan,nan
# done with 233,250:-35,1
# done with 0,256:nan,nan
# done with 142,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 72,253:-35,0
# done with 185,250:-35,1
# done with 138,253:-35,0
# done with 173,251:-35,1
# done with 0,256:nan,nan
# done with
#  198,250:-35,1
# done with 0,256:nan,nan
# done with 107,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 37,253:-35,0
# done with 150,250:-35,1
# done with 103,253:-35,0
# done with 138,251:-35,1
# done with 0,256:nan,nan
# done with 163,250:-35,1
# done with 0,256:nan,nan
# done with 72,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 2,253:-34,0
# done with 115,250:-35,1
# done with 68,253:-35,0
# done with 103,251:-35,1
# done with 0,256:nan,nan
# done with
#  128,250:-35,1
# done with 0,256:nan,nan
# done with 37,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 992,253:-34,0
# done with 80,250:-35,1
# done with 33,253:-35,0
# done with 68,251:-35,1
# done with 0,256:nan,nan
# done with 93,250:-35,1
# done with 0,256:nan,nan
# done with 2,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 957,253:-35,0
# done with 45,250:-35,1
# done with 1023,253:-35,0
# done with 33,251:-35,1
# done with 0,256:nan,nan
# done with
#  58,250:-35,1
# done with 0,256:nan,nan
# done with 992,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 922,253:-35,0
# done with 10,250:-35,1
# done with 988,253:-35,0
# done with 1023,251:-35,1
# done with 0,256:nan,nan
# done with 23,250:-35,1
# done with 0,256:nan,nan
# done with 957,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 887,253:-35,0
# done with 1000,250:-35,1
# done with 953,253:-35,0
# done with 988,251:-35,1
# done with 0,256:nan,nan
# done with
#  1013,250:-35,1
# done with 0,256:nan,nan
# done with 922,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 852,253:-35,0
# done with 965,250:-35,1
# done with 918,253:-35,0
# done with 953,251:-35,1
# done with 0,256:nan,nan
# done with 978,250:-35,1
# done with 0,256:nan,nan
# done with 887,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 817,253:-35,0
# done with 930,250:-35,1
# done with 883,253:-35,0
# done with 918,251:-35,1
# done with 0,256:nan,nan
# done with
#  943,250:-35,1
# done with 0,256:nan,nan
# done with 852,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 782,253:-35,0
# done with 895,250:-35,1
# done with 848,253:-35,0
# done with 883,251:-35,1
# done with 0,256:nan,nan
# done with 908,250:-35,1
# done with 0,256:nan,nan
# done with 817,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 747,253:-35,0
# done with 860,250:-35,1
# done with 813,253:-35,0
# done with 848,251:-35,1
# done with 0,256:nan,nan
# done with
#  873,250:-35,1
# done with 0,256:nan,nan
# done with 782,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 712,253:-35,0
# done with 825,250:-35,1
# done with 778,253:-35,0
# done with 813,251:-35,1
# done with 0,256:nan,nan
# done with 838,250:-35,1
# done with 0,256:nan,nan
# done with 747,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 677,253:-35,0
# done with 790,250:-35,1
# done with 743,253:-35,0
# done with 778,251:-35,1
# done with 0,256:nan,nan
# done with
#  803,250:-35,1
# done with 0,256:nan,nan
# done with 712,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 642,253:-35,0
# done with 755,250:-35,1
# done with 708,253:-35,0
# done with 743,251:-35,1
# done with 0,256:nan,nan
# done with 768,250:-35,1
# done with 0,256:nan,nan
# done with 677,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 607,253:-35,0
# done with 720,250:-35,1
# done with 673,253:-35,0
# done with 708,251:-35,1
# done with 0,256:nan,nan
# done with
#  733,250:-35,1
# done with 0,256:nan,nan
# done with 642,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 572,253:-35,0
# done with 685,250:-35,1
# done with 638,253:-35,0
# done with 673,251:-35,1
# done with 0,256:nan,nan
# done with 698,250:-35,1
# done with 0,256:nan,nan
# done with 607,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 537,253:-35,0
# done with 650,250:-35,1
# done with 603,253:-35,0
# done with 638,251:-35,1
# done with 0,256:nan,nan
# done with
#  663,250:-35,1
# done with 0,256:nan,nan
# done with 572,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 502,253:-35,0
# done with 615,250:-35,1
# done with 568,253:-35,0
# done with 603,251:-35,1
# done with 0,256:nan,nan
# done with 628,250:-35,1
# done with 0,256:nan,nan
# done with 537,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 467,253:-35,0
# done with 580,250:-35,1
# done with 533,253:-35,0
# done with 568,251:-35,1
# done with 0,256:nan,nan
# done with
#  593,250:-35,1
# done with 0,256:nan,nan
# done with 502,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 432,253:-35,0
# done with 545,250:-35,1
# done with 498,253:-35,0
# done with 533,251:-35,1
# done with 0,256:nan,nan
# done with 558,250:-35,1
# done with 0,256:nan,nan
# done with 467,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 397,253:-35,0
# done with 510,250:-35,1
# done with 463,253:-35,0
# done with 498,251:-35,1
# done with 0,256:nan,nan
# done with
#  523,250:-35,1
# done with 0,256:nan,nan
# done with 432,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 362,253:-35,0
# done with 475,250:-35,1
# done with 428,253:-35,0
# done with 463,251:-35,0
# done with 0,256:nan,nan
# done with 488,250:-35,1
# done with 0,256:nan,nan
# done with 397,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 327,253:-35,0
# done with 440,250:-35,1
# done with 393,253:-35,0
# done with 428,251:-35,0
# done with 0,256:nan,nan
# done with
#  453,250:-35,1
# done with 0,256:nan,nan
# done with 362,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 292,253:-35,0
# done with 405,250:-35,1
# done with 358,253:-35,0
# done with 393,251:-35,0
# done with 0,256:nan,nan
# done with 418,250:-35,1
# done with 0,256:nan,nan
# done with 327,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 257,253:-35,0
# done with 370,250:-35,1
# done with 323,253:-35,0
# done with 358,251:-35,0
# done with 0,256:nan,nan
# done with
#  383,250:-35,1
# done with 0,256:nan,nan
# done with 292,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 222,253:-35,0
# done with 335,250:-35,1
# done with 288,253:-35,0
# done with 323,251:-35,0
# done with 0,256:nan,nan
# done with 348,250:-35,1
# done with 0,256:nan,nan
# done with 257,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 187,253:-35,0
# done with 300,250:-35,1
# done with 253,253:-35,0
# done with 288,251:-35,0
# done with 0,256:nan,nan
# done with
#  313,250:-35,1
# done with 0,256:nan,nan
# done with 222,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 152,253:-35,0
# done with 265,250:-35,1
# done with 218,253:-35,0
# done with 253,251:-35,0
# done with 0,256:nan,nan
# done with 278,250:-35,1
# done with 0,256:nan,nan
# done with 187,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 117,253:-35,0
# done with 230,250:-35,1
# done with 183,253:-35,0
# done with 218,251:-35,1
# done with 0,256:nan,nan
# done with
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# -c:140: RuntimeWarning: invalid value encountered in divide
# -c:140: RuntimeWarning: divide by zero encountered in double_scalars
# -c:124: RuntimeWarning: invalid value encountered in add
# To exit: use 'exit', 'quit', or Ctrl-D.
#  243,250:-35,1
# done with 0,256:nan,nan
# done with 152,253:-35,0
# done with 0,256:nan,nan
# done with 0,256:nan,nan
# done with 82,253:-35,0
# done with 195,250:-35,1
# done with 148,253:-35,0
# done with 183,251:-35,1
# done with 0,256:nan,nan

# %% [markdown]
# ## References
#
# [1]() Craig W. Reynolds. Flocks, Herds and Schools: A Distributed Behavioral Model. In _ACM SIGGRAPH Computer Graphics_, Volume 21, pp. 25-34. ACM, 1987.
#
# **Description:** The original boids algorithm paper
#
# [2](http://www.pygame.org/docs/tut/intro/intro.html) Pete Shinners. Python Pygame Introduction. http://www.pygame.org/docs/tut/intro/intro.html. Accessed 30 November 2013.
#
# **Description:** Tutorial for using PyGame where I took the basic structure of the code
#
# [3](http://www.kfish.org/boids/pseudocode.html) Conrad Parker. Boids Pseudocode. http://www.kfish.org/boids/pseudocode.html, 1995. Last Modified 06 September 2007. Accessed 01 December 2013.
#
# **Description:** Pseudocode for the boids algorithm, with some additional notes and analysis.
#
# [4](http://www.lionking.org/movies/Stampede.mov) Stampede Sequence from Disney's *The Lion King*, 1995. Available online at: http://www.lionking.org/movies/Stampede.mov. Originally Accessed from http://www.red3d.com/cwr/boids/.
#
# **Description:** "Quick, Stampede, in the gorge. Simba's down there!"
#
# [5](http://en.wikipedia.org/wiki/Cellular_automaton "Cellular Automata") "Cellular Automata on *Wikipedia.org*. http://en.wikipedia.org/wiki/Cellular_automaton. Accessed 02 December 2013."
#
# **Description:** If you find this type of distributed, dynamical system interesting, you may also be interested in cellular automata.
